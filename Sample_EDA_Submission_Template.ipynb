# %% [markdown]
# <a href="https://colab.research.google.com/github/Methelesh-Suresh/EDA-Capstone-Project/blob/main/Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - *AirBnB NYC*

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
# https://github.com/Methelesh-Suresh/EDA-Capstone-Project/blob/main/Sample_EDA_Submission_Template.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Airbnb project/Copy of Airbnb NYC 2019.csv'
data = pd.read_csv(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(data[data.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(data.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset comprises 48,895 Airbnb listings, each detailed by 16 features. These features provide insights into various aspects of the accommodations, including location, host information, room type, pricing, availability, and guest reviews.
#
# However, the dataset contains missing values in certain columns, which may require data cleaning or imputation before conducting a comprehensive analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
data.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   **id:** A unique identifier for each listing.
# *   **name:** The name or title given to the listing.
# *   **host_id:** A unique identifier for the host of the listing.
# *   **host_name:** The name of the host.
# *   **neighbourhood_group:** The broader geographic area where the listing is located.
# *   **neighbourhood:** The specific neighborhood within the neighbourhood group.
# *   **latitude:** The geographic latitude of the listing.
# *   **longitude:** The geographic longitude of the listing.
# *   **room_type:** The type of room offered (e.g., Entire home/apt, Private room, Shared room).
# *   **price:** The nightly price of the listing.
# *   **minimum_nights:** The minimum number of nights required for a stay.
# *   **number_of_reviews:** The total number of reviews received for the listing.
# *   **last_review:** The date of the last review.
# *   **reviews_per_month:** The average number of reviews received per month.
# *   **calculated_host_listings_count:** The total number of listings hosted by the host.
# *   **availability_365:** The number of days the listing is available for booking in the next 365 days.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in data.columns.tolist():
  print("No. of unique values in ",i,"is",data[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df = data.copy()
df_reviews = data.copy()
df['name'].fillna('Unknown', inplace=True)
df['host_name'].fillna('Not Provided', inplace=True)
df['reviews_per_month'].fillna(0, inplace=True)
df['last_review'].fillna('Not Updated', inplace=True)
df_reviews.dropna(subset=['reviews_per_month'], inplace= True)

# %%
df_reviews['reviews_per_month'] = df_reviews['reviews_per_month'].round(1).astype(str)
df_reviews['reviews_per_month'] = df_reviews['reviews_per_month'].apply(lambda x: x + '.0' if '.' not in x else x)

# %%
print(df.isnull().sum())
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 "Average Reviews per Month"

# %%
#Average Reviews per Month

df_reviews['reviews_per_month'] = pd.to_numeric(df_reviews['reviews_per_month'], errors='coerce')
neighbourhood_reviews = df_reviews.groupby('neighbourhood_group')['reviews_per_month'].mean()
sorted_reviews = neighbourhood_reviews.sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.heatmap(sorted_reviews.to_frame(), annot=True, cmap='viridis')
plt.title('Average Reviews per Month by Neighbourhood Group')
plt.ylabel('Neighbourhood Group')
plt.xlabel('Average Reviews per Month')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This visual is to compare the average reviews per month across different neighborhoods groups. Warmer colors indicate higher average reviews, while cooler colors indicate lower average reviews. This helps us quickly identify top-performing and underperforming neighborhoods groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the heatmap, we can see that the top performing neighborhood group are Staten Island and Queens, both having an average rating of 1.6, while the least perfoming neigbhorhood group is Manhattan which has 0.98

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing average reviews per neighborhood, we can gain valuable insights that can positively impact the business. Here are a few ways:
#
# *   **Targeted Marketing:** Identify high-performing neighborhoods and tailor marketing efforts to attract more visitors to these areas.
# *   **Improved Property Management:** Focus on improving properties in low-performing neighborhoods to boost their ratings and attract more guests.
# *   **Optimized Pricing Strategy:** Adjust pricing strategies based on neighborhood performance. High-performing neighborhoods might justify premium pricing.
# *   **Enhanced Guest Experience:** Use insights to identify areas where guest satisfaction can be improved, such as cleanliness, amenities, or host communication.
# *   **Strategic Partnerships:** Collaborate with local businesses in high-performing neighborhoods to offer bundled deals or exclusive experiences for guests.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
k = df['neighbourhood_group'].value_counts()
k.plot(kind = 'pie', autopct='%1.1f%%', labels = None)
plt.title('Neighbourhood Group Distribution', loc = 'center', fontsize = '15')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Total Visits')
plt.legend(k.index, bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is an ideal visualization for categorical data like neighborhood groups, especially when the goal is to show the proportion of each category within a whole. It visually represents the distribution of visits across different neighborhoods groups, making comparisons easy. Larger slices indicate a higher proportion of visits, providing a clear understanding of the relative importance of each neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart shows that Manhattan has the highest overall number of visits, accounting for 44.3%, followed by Brooklyn with 41.1%. Staten Island receives the fewest visitors, accounting for only 0.8% of all visits.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the distribution of visits across different neighborhoods, businesses can make informed decisions to:
#
# *   **Optimize Resource Allocation:** Businesses can allocate resources, such as marketing budgets and staffing, to areas with higher visitor traffic. For example, businesses in Manhattan could invest in targeted marketing campaigns to attract even more visitors.
# *   **Tailor Marketing Strategies:** By analyzing the specific characteristics of each neighborhood, businesses can tailor their marketing messages and promotions to resonate with local preferences and interests.
# *   **Improve Customer Experience:** Understanding the needs and preferences of visitors from different neighborhoods can help businesses enhance their offerings and services. For example, businesses in neighborhoods with a high concentration of families could focus on providing family-friendly amenities.
# *   **Identify Potential Partnerships:** Businesses can collaborate with local organizations and attractions in popular neighborhoods to cross-promote each other and attract more visitors.
# *   **Monitor Trends and Adapt:** By tracking visitor trends over time, businesses can identify emerging opportunities and challenges. This allows them to adapt their strategies to changing market conditions.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import plotly.express as px
fig = px.scatter_mapbox(df, lat='latitude', lon='longitude', color='price', hover_name='neighbourhood', zoom=10)
fig.update_layout(mapbox_style="open-street-map")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The map visualization is an excellent choice for this dataset because it allows for the spatial representation of data points with geographical coordinates. In this case, the map effectively visualizes the distribution of property prices across different locations in New York City and its surrounding areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The map clearly shows a wide range of property prices across different locations. The color gradient indicates that prices tend to be higher in certain areas, such as Manhattan and parts of Brooklyn, while they are lower in other areas like Staten Island and some parts of Queens and the Bronx.
#
# There are distinct clusters of high-priced properties in Manhattan, particularly in areas like Midtown, Upper East Side, and Lower Manhattan. Similar clusters can be observed in parts of Brooklyn and some coastal areas of Long Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **Real Estate:** Real estate agents and developers can use this information to understand market trends, identify areas with high demand and potential for appreciation, and price properties competitively.
# *   **Financial Services:** Lenders and investors can assess risk and make informed decisions about mortgage lending and investment opportunities based on the spatial distribution of property values.
# *   **Retail and Hospitality:** Businesses in the retail and hospitality sectors can use this information to identify areas with high foot traffic and potential customer base, and make informed decisions about location and expansion strategies.
# *   **Urban Planning:** Urban planners and policymakers can use this data to understand the spatial patterns of development, identify areas with high housing demand, and plan for infrastructure and amenities accordingly.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(x='neighbourhood_group', y='price', data=df, palette='viridis')
plt.title('Price Distribution by Neighborhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is a great visual tool to understand the price distribution across different neighborhood groups. It clearly shows the median price, the range of prices, and any outliers. This helps users quickly identify affordable neighborhoods, compare price variations, and make informed decisions about their Airbnb stays.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that different neighborhoods in the city have different price ranges for Airbnb listings. Manhattan and Brooklyn are generally more expensive than Queens, Staten Island, and Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the price distribution across different neighborhoods, Airbnb can make several positive business impacts:
#
# *   **Targeted Marketing:** They can tailor marketing campaigns to specific neighborhoods, highlighting their unique pricing and offerings.
# *   **Optimized Pricing Strategy:** They can adjust pricing strategies based on neighborhood demand and competition.
# *   **Improved User Experience:** They can provide more accurate search results and recommendations based on users' budget preferences.
# *   **Enhanced Host Support:** They can offer guidance to hosts on pricing strategies and marketing their listings effectively.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='room_type', y='price', data=df, ci=None, palette='viridis')
plt.title('Average Price by Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective in comparing the average values of a variable across different categories. In this case, the chart clearly shows the average price for each room type (Private room, Entire home/apt, and Shared room), allowing for easy comparison of their relative pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average price for "Entire home/apt" is significantly higher than the other two room types, indicating that renting an entire home or apartment is generally more expensive than renting a private room or sharing a room with others. The average price for "Shared room" is the lowest, making it the most budget-friendly option for travelers looking to save on accommodation costs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **Airbnb Hosts:** Understanding the average price for different room types can help hosts set competitive prices for their listings. They can adjust their pricing based on the type of room they offer and the amenities provided.
# *   **Travelers:** The chart provides valuable information for travelers to make informed decisions about their accommodation choices. They can choose the room type that best suits their budget and preferences.
# *   **Tourism Industry:** The insights can be used to understand the pricing trends in the accommodation market and identify opportunities for growth and innovation. For example, businesses can develop new offerings or packages that cater to specific segments of travelers.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(x='room_type', data=df, palette='viridis')
plt.title('Number of Listings by Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective in comparing the frequencies or counts of different categories. In this case, the chart clearly shows the number of listings available for each room type (Private room, Entire home/apt, and Shared room), allowing for easy comparison of their relative popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of listings for "Entire home/apt" is significantly higher than the other two room types, indicating that this is the most popular type of listing among hosts. The number of listings for "Shared room" is the lowest, indicating that this type of accommodation is less prevalent compared to the other two options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **Airbnb Hosts:** Understanding the distribution of listings across different room types can help hosts make informed decisions about the type of listing to offer. They can choose the room type that is most in demand and adjust their offerings accordingly.
# *   **Travelers:** The chart provides valuable information for travelers to understand the availability of different room types and make informed decisions about their accommodation choices.
# *   **Tourism Industry:** The insights can be used to understand the overall supply and demand for different types of accommodation and identify opportunities for growth and innovation. For example, businesses can develop new offerings or packages that cater to specific segments of travelers.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10, 6))
sns.heatmap(df.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack(), annot=True, fmt='.2f')
plt.title('Average Price by Neighborhood Group and Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this specific chart as we can use it to compare the average prices of different room types across various neighborhood groups. This helps us quickly identify which neighborhoods and room types have higher or lower average prices, providing valuable insights for both hosts and guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals that Manhattan and Brooklyn are the most expensive neighborhoods for Airbnb listings, particularly for entire home/apartment rentals. For instance, the average price for an entire home/apartment in Manhattan is significantly higher than in other neighborhoods.
#
# On the other hand, Staten Island offers the most affordable options, especially for shared rooms. However, even in Staten Island, entire home/apartment rentals tend to be more expensive than private rooms or shared rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding these pricing trends, Airbnb can make several strategic improvements:
#
# **1) Targeted Marketing:**
#
# *   **Premium Listings:** Target high-end travelers to Manhattan and Brooklyn with luxury listings.
# *   **Budget-Friendly Options:** Promote Staten Island and Queens as affordable destinations.
#
# **2) Optimized Pricing Strategies:**
#
# *   **Dynamic Pricing:** Implement dynamic pricing strategies based on demand and seasonality, especially in high-demand neighborhoods like Manhattan.
# *   **Competitive Pricing:** Analyze competitor pricing in each neighborhood to ensure competitive pricing.
#
# **3) Enhanced User Experience:**
#
# *   **Personalized Recommendations:** Recommend listings based on user budget and preferred neighborhood.
# *   **Transparent Pricing:** Clearly display all fees and taxes to avoid surprises.
#
# **4) Host Support:**
#
# *   Provide guidance to hosts on optimal pricing strategies based on their location and room type.
# *   Help hosts understand factors influencing demand and adjust their pricing accordingly.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
host_counts = df['host_name'].value_counts().head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x=host_counts.index, y=host_counts.values, palette='viridis')
plt.title('Top 5 Hosts by Number of Listings')
plt.xlabel('Host Name')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this spesific chart as it clearly shows the number of listings for each of the top 5 hosts, allowing for easy comparison of their relative market share.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 5 hosts have a significant number of listings, indicating a high concentration of properties within a few hands. This suggests that the market might have some level of concentration.
#
# "Michael" and "David" have the highest number of listings, indicating their dominance in the market.
#
# "Sonder (NYC)" is also a major player with a considerable number of listings, suggesting the presence of professional property management companies or large-scale operators in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  **Airbnb:** Understanding the market share of top hosts can help Airbnb identify potential areas for improvement, such as promoting diversity among hosts and ensuring fair competition.
# *   **New Hosts:** The chart can provide insights into the competitive landscape and help new hosts understand the level of competition they might face.
# *  **Policymakers:** The information can be used to analyze the impact of short-term rentals on the housing market and develop policies to ensure a balanced and sustainable market

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood_group', y='availability_365', data=df, ci=None, palette='viridis')
plt.title('Average Availability by Neighborhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective in comparing the average values of a variable across different categories. In this case, the chart clearly shows the average availability (presumably in days) for each neighborhood group, allowing for easy comparison of their relative availability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Staten Island has the highest average availability, suggesting that there are more listings available for longer periods in this borough. Manhattan has the lowest average availability, indicating that listings in this borough tend to be booked more frequently and have shorter vacancy periods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  **Airbnb Hosts:** Understanding the average availability in different neighborhoods can help hosts make informed decisions about their listing strategy. For instance, hosts in Manhattan might need to consider strategies to increase their occupancy rates, such as offering flexible cancellation policies or implementing dynamic pricing.
# *  **Travelers:** The chart provides valuable information for travelers to understand the availability of listings in different neighborhoods. This can help them plan their trips and secure accommodations in advance, especially during peak seasons.
# *  **Tourism Industry:** The insights can be used to analyze the overall availability of short-term rentals in different areas and identify potential bottlenecks or areas with high demand. This information can be used to inform tourism planning and development strategies.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Group by room_type and sum the number_of_reviews
total_reviews_by_room_type = df.groupby('room_type')['number_of_reviews'].sum().sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=total_reviews_by_room_type.index, y=total_reviews_by_room_type.values, palette='viridis')
plt.title('Total Reviews by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Total Reviews')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  The chart clearly shows the total number of reviews for each room type (Entire home/apt, Private room, and Shared room), allowing for easy comparison of their relative popularity and usage.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The total number of reviews for "Entire home/apt" is significantly higher than the other two room types, indicating that this type of listing receives the most reviews and is likely the most frequently used. The total number of reviews for "Shared room" is the lowest, indicating that this type of listing receives fewer reviews and is likely less frequently used compared to the other two options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  **Airbnb:** Understanding the distribution of reviews across different room types can help Airbnb identify areas for improvement in terms of user experience and service quality for each room type.
# *  **Hosts:** The chart can provide insights into the relative popularity of different room types and help hosts make informed decisions about the type of listing to offer.
# *  **Travelers:** The information can be used to understand the relative popularity and usage of different room types and make informed decisions about their accommodation choices

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='number_of_reviews', data=df, hue='room_type', palette='viridis')
plt.title('Price vs. Number of Reviews')
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.legend(title='Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are effective in showing the distribution of data points across two variables. In this case, the scatter plot clearly shows how the number of reviews varies with price for different room types, allowing us to identify potential trends and patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  There appears to be an inverse relationship between price and the number of reviews. As the price increases, the number of reviews tends to decrease. This suggests that more expensive listings might receive fewer reviews, possibly due to lower occupancy rates or a smaller pool of guests willing to pay higher prices.
#
# *  There is a dense cluster of listings with low prices and a moderate number of reviews. This suggests that a large portion of listings fall within this category.
#
# *  There is a dense cluster of listings with low prices and a moderate number of reviews. This suggests that a large portion of listings fall within this category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  **Airbnb Hosts:** Understanding the relationship between price and reviews can help hosts optimize their pricing strategy. By analyzing the price points that attract the most reviews, hosts can adjust their prices to maximize both occupancy and positive reviews.
# *  **Travelers:** The scatter plot provides valuable information for travelers to understand the relationship between price and review volume. They can use this information to make informed decisions about their accommodation choices, balancing price with the number of reviews and guest feedback.
# *  **Airbnb:** The insights can be used to analyze the overall market dynamics and identify areas for improvement in terms of user experience and service quality. For example, Airbnb can investigate factors that contribute to lower review counts for higher-priced listings and work to address these issues.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# Check for any NaT values in last_review
if df['last_review'].isnull().any():
    print("Warning: Some last review dates could not be converted and are set to NaT.")

# Group by month and count the number of reviews
reviews_over_time = df.groupby(df['last_review'].dt.to_period('M')).size()

# Plotting
plt.figure(figsize=(10, 6))
reviews_over_time.plot(kind='line', marker='o')
plt.title('Number of Reviews Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are effective in showing trends and patterns in data over a continuous period. In this case, the line chart clearly shows how the number of reviews has changed from 2012 to 2019, allowing us to identify any significant trends or growth patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The number of reviews has increased significantly over time, particularly from 2018 onwards. This suggests that the platform has gained popularity and usage over the years
# *   From 2012 to around 2017, the growth in reviews was relatively steady, indicating a gradual increase in platform usage.
# *  The number of reviews experienced a sharp increase in 2018 and 2019, suggesting a period of rapid growth and increased platform adoption.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  **Airbnb:** Understanding the historical growth in reviews can help Airbnb plan for future growth and resource allocation. It can also provide insights into the factors driving platform usage and inform marketing and product development strategies.
# *  **Investors:** The chart can provide valuable information about the platform's growth trajectory and user engagement, which can be used to assess the company's performance and potential for future growth.
# *  **Researchers:** The data can be used to analyze the factors driving the growth in reviews and understand the evolution of the short-term rental market.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# **Increase bookings:**
#
# *  Identify underperforming neighborhoods and develop targeted marketing campaigns to attract more guests.
# Analyze the relationship between price and reviews to optimize pricing strategies and encourage more bookings.
# Offer guidance to hosts on improving their listings and property management practices to increase guest satisfaction and attract more bookings.
#
# **Improve user experience:**
#
# *  Address the concentration of listings among a few hosts by implementing policies or programs that encourage a more balanced distribution of listings across different hosts.
# Provide recommendations to hosts on how to improve their listings based on factors such as amenities, pricing, and guest reviews.
# Partner with local businesses in high-performing neighborhoods to offer bundled deals or exclusive experiences for guests.
#
# **Expand market share:**
#
# *  Analyze the availability of listings in different neighborhoods to identify areas with high demand and potential for growth.
# Develop strategies to attract new hosts, particularly in neighborhoods with lower availability.
# Partner with tourism boards or local authorities to promote Airbnb as a viable accommodation option for travelers.
#
# **High-performing neighborhoods:**
#
# *  Staten Island and Queens have the highest average review ratings, while Manhattan has the lowest. This suggests that guests may be more satisfied with listings in Staten Island and Queens, potentially due to factors such as affordability, amenities, or a sense of community.
#
# **Room type preferences:**
# *   Entire home/apartment listings are the most popular and expensive, followed by private rooms and shared rooms. This suggests that travelers value privacy and space but are also interested in more budget-friendly options.
#
# **Top hosts:**
# *  A small number of hosts control a significant portion of listings. This could indicate a trend towards professionalization in the Airbnb market.
#
# **Seasonality:**
# *  The number of reviews may vary depending on the season. This information can be used to develop targeted marketing campaigns and adjust pricing strategies throughout the year.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Overall Conclusions:**
#
# *  **New York City Airbnb Market is Diverse and Dynamic:** The analysis reveals a diverse and dynamic Airbnb market in New York City with significant variations in pricing, availability, and guest behavior across different neighborhoods and room types.
# *  **Manhattan and Brooklyn Dominate:** These boroughs exhibit high demand, higher prices, and lower average reviews per month.
# *  **Staten Island and Queens Offer Value:** These boroughs present opportunities for travelers seeking more affordable options with potentially higher guest satisfaction.
# *  **Entire Homes/Apartments are Popular but Expensive:** This room type dominates the market in terms of both number of listings and average price.
# *  **Market Concentration:** A few top hosts control a significant number of listings, indicating potential market concentration.
# Growth and Evolution: The market has experienced significant growth in recent years, with a notable increase in reviews and platform usage.
# Business Implications:
#
# **Future Research Directions:**
#
# *  **Seasonality Analysis:** Investigate the impact of seasonality on pricing, demand, and review patterns.
# *  **Competitive Analysis:** Analyze the competitive landscape and identify areas where Airbnb can differentiate itself from competitors.
# *  **Impact on Local Communities:** Conduct further research on the impact of short-term rentals on local housing markets, affordability, and community dynamics.
#
#
# Overall, the analysis provides valuable insights into the New York City Airbnb market, highlighting key trends, challenges, and opportunities. These insights can be used by Airbnb, travelers, policymakers, and other stakeholders to make informed decisions and shape the future of the short-term rental market in the city.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
